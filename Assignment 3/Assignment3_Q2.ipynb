# %%
import numpy as np
import cv2 as cv
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow

# %%
def Equalize(n):

  # read the required image
  path = '/content/cctv' + n + '.JPG'
  image = cv.imread(path)

  # convert image from RGB to HSV
  img_hsv = cv.cvtColor(image, cv.COLOR_RGB2HSV)

  # Histogram equalisation on the V-channel
  img_hsv[:, :, 2] = cv.equalizeHist(img_hsv[:, :, 2])

  # convert image back from HSV to RGB
  image = cv.cvtColor(img_hsv, cv.COLOR_HSV2RGB)

  cv2_imshow(image)

  return

# %%
n = str(input("Enter the image number (1 to 4) to inspect: "))
Equalize(n)
# Out:
# Enter the image number (1 to 4) to inspect: 1
# <PIL.Image.Image image mode=RGB size=399x298 at 0x7F97E42A0B20>
